# %%
import pandas as pd

data = pd.read_csv("../Data/Processed/clean_data.csv")

# %%
data.head(10)
# Out:
#    Unnamed: 0                                         clean_text  \
# 0           0                                          what said
# 1           1  plus youve added commercials to the experience...
# 2           2  i didnt today must mean i need to take another...
# 3           3  its really aggressive to blast obnoxious enter...
# 4           4            and its a really big bad thing about it
# 5           5  seriously would pay a flight for seats that di...
# 6           6  yes nearly every time i fly vx this ear worm w...
# 7           7  really missed a prime opportunity for men with...
# 8           8                         well i didntbut now i do d
# 9           9  it was amazing and arrived an hour early youre...
#
#   airline_sentiment         airline
# 0           neutral  Virgin America
# 1          positive  Virgin America
# 2           neutral  Virgin America
# 3          negative  Virgin America
# 4          negative  Virgin America
# 5          negative  Virgin America
# 6          positive  Virgin America
# 7           neutral  Virgin America
# 8          positive  Virgin America
# 9          positive  Virgin America

# %%
from sentence_transformers import  SentenceTransformer
model=SentenceTransformer(
    "cardiffnlp/twitter-roberta-base-sentiment"
)
# Out:
# No sentence-transformers model found with name cardiffnlp/twitter-roberta-base-sentiment. Creating a new one with mean pooling.
# Some weights of RobertaModel were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
texts=data["clean_text"].tolist()

# %%
embeddings=model.encode(
    texts,
    show_progress_bar=True
)
# Out:
# Batches: 100%|██████████| 451/451 [04:10<00:00,  1.80it/s]

# %%
data['embeddings']=list(embeddings)

# %%
data=data.drop(columns=[
    'Unnamed: 0'
])

# %% [markdown]
# [0.09349196, 0.22166443, -0.10611222, 0.148594...]

# %%
data.head()
# Out:
#                                           clean_text airline_sentiment  \
# 0                                          what said           neutral
# 1  plus youve added commercials to the experience...          positive
# 2  i didnt today must mean i need to take another...           neutral
# 3  its really aggressive to blast obnoxious enter...          negative
# 4            and its a really big bad thing about it          negative
#
#           airline                                         embeddings
# 0  Virgin America  [-0.14999603, -0.53225005, -0.14324617, -0.822...
# 1  Virgin America  [-0.025072118, -0.5276757, -0.16144873, -0.449...
# 2  Virgin America  [-0.13152163, -0.5167499, 0.09803597, -0.75049...
# 3  Virgin America  [0.0893467, -0.4533559, 0.019523002, -0.772465...
# 4  Virgin America  [-0.10262265, -0.60638845, 0.27071747, -0.6140...

# %% [markdown]
# **Création des identifiants**

# %%
data['id'] = [f"review_{i}" for i in range(len(data))]

# %% [markdown]
# **Split train / test**

# %%
import numpy as np
from sklearn.model_selection import train_test_split

data_train, data_test = train_test_split(
    data,
    test_size=0.2,
    random_state=42,
    stratify=data['airline_sentiment'] 
    )

# %%
data_train.head()
# Out:
#                                               clean_text airline_sentiment  \
# 7624   no not boarding order someone boarded with ser...          negative
# 9783   sucks delayed my moms flight x cancelled fligh...          negative
# 7088                              rt our fleets on fleek           neutral
# 2157   when i read it say in some cases can you pleas...          negative
# 12118  i am dealing with the reflight booking problem...           neutral
#
#           airline                                         embeddings  \
# 7624        Delta  [-0.030747607, -0.48066524, -0.099700734, -0.8...
# 9783   US Airways  [-0.024749225, -0.19862664, -0.079210095, -0.7...
# 7088        Delta  [-0.13899958, -0.6026296, -0.037226222, -0.307...
# 2157       United  [-0.029725853, -0.9434178, -0.061759353, -0.50...
# 12118    American  [-0.18219015, -0.33504093, 0.011790585, -0.755...
#
#                  id
# 7624    review_7624
# 9783    review_9783
# 7088    review_7088
# 2157    review_2157
# 12118  review_12118

# %%
data_test.head()
# Out:
#                                              clean_text airline_sentiment  \
# 5868  why doesnt your terminal b in lga have prechec...          negative
# 1125  b boarding this attendant took his shoe ampsoc...          negative
# 5765                                   link doesnt work          negative
# 710   it was ua flight now im currently stuck in por...          negative
# 3582  i forgot that intl flights out of lax dont go ...          positive
#
#         airline                                         embeddings  \
# 5868  Southwest  [-0.012143357, -0.062115833, -0.18422022, -0.8...
# 1125     United  [0.038747367, -0.77709734, -0.3220472, -1.3697...
# 5765  Southwest  [-0.31305444, -0.20537896, -0.17505193, -0.825...
# 710      United  [-0.38896766, -0.113024004, -0.099490106, -0.6...
# 3582     United  [0.06962187, -0.40473652, -0.25463948, -0.7262...
#
#                id
# 5868  review_5868
# 1125  review_1125
# 5765  review_5765
# 710    review_710
# 3582  review_3582

# %%
print(data_train.shape, data_test.shape)
print(data_train['airline_sentiment'].value_counts(normalize=True))
print(data_test['airline_sentiment'].value_counts(normalize=True))
# Out:
# (11541, 5) (2886, 5)
# airline_sentiment
# negative    0.629408
# neutral     0.211853
# positive    0.158738
# Name: proportion, dtype: float64
# airline_sentiment
# negative    0.629245
# neutral     0.212058
# positive    0.158697
# Name: proportion, dtype: float64

# %% [markdown]
# **Initialisation ChromaDB**

# %%
import chromadb
from chromadb.config import Settings

# %%
CHROMA_PATH = "../chroma_db"

# %%
clients = chromadb.PersistentClient(path=CHROMA_PATH)

# %% [markdown]
# **Créer les collections**

# %%
train_collection = clients.get_or_create_collection(
    name="airline_train_embeddings",metadata={"hnsw:space" : "cosine"}
)

test_collection = clients.get_or_create_collection(
    name="airline_test_embeddings",metadata={"hnsw:space" : "cosine"}
)

# %% [markdown]
# **Stockage TRAIN/TEST dans ChromaDB**

# %%
from tqdm import tqdm

def add_to_chroma(collection,df,batch_size=2000):
    # Ajoute les embeddings d'un DataFrame dans ChromaDB par batch.

    for start in tqdm(range(0,len(df),batch_size),desc=f"{collection.name}"):
        batch=df[start:start+batch_size]

        collection.add(
            ids=batch["id"].tolist(),
            embeddings=[e.tolist() for e in batch["embeddings"]],
            metadatas=batch[["airline", "airline_sentiment", "clean_text"]].to_dict("records"),
        )

add_to_chroma(train_collection, data_train)
add_to_chroma(test_collection, data_test)
# Out:
# airline_train_embeddings: 100%|██████████| 6/6 [00:06<00:00,  1.07s/it]
# airline_test_embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.07it/s]
